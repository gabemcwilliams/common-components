# %%
import pandas as pd
from minio import Minio
import re
import requests
import traceback
import inspect
from pprint import pprint
import os
import datetime as dt
import hvac
import yaml

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# %%
class ParquetFileObjectsDownload:

    def __init__(self, cache_dir:str="d:/cache/", clear_cache:bool=False) -> None:
        if clear_cache:
            print("-" * 50)
            print(f"Clearing cache: {cache_dir}")

            for root, dirs, files in os.walk(cache_dir):
                for file in files:
                    if file.endswith(".parquet"):
                        os.remove(f"{root}/{file}")
                        print(f"Removed {root}/{file}")

            print("-" * 50 + "\n")

        self.__cache_dir = cache_dir
        # Get secret information for Minio Client
        self.__secrets = self.read_secret(mount_point="localhost",
                                          path="minio/jetbrains")
        self.__minio_client = self.__create_minio_client__()["data"]
        self.__objects_list = self.create_object_list()
        self.download_objects(self.__objects_list, self.__cache_dir)

    @staticmethod
    def read_secret(mount_point: str, path: str) -> dict:
        ca_path = os.environ.get("SSL_CERT_FILE")
        client = hvac.Client(verify=ca_path)
        print(f"client is authenticated: {client.is_authenticated}")
        resp = client.secrets.kv.read_secret(mount_point=mount_point, path=f'/{path}')
        secret = resp['data']['data']

        return secret

    @staticmethod
    def __read_yaml_query__(yaml_dir:str=(os.getcwd())) -> dict|None:
        try:
            with open(os.path.join(yaml_dir, "query.yaml"), "r") as f:
                data = (yaml.safe_load(f))["QUERY"]

                return data

        except Exception as e:
            print(e)
            return None

    def __create_minio_client__(self):
        try:
            minio_client = Minio(
                endpoint=re.sub("https?://", "", self.__secrets["url"]),
                secure=True,
                access_key=self.__secrets["accessKey"],
                secret_key=self.__secrets["secretKey"]
            )

            return {
                "data": minio_client,
                "result": {
                    "status_code": 200,
                    "message": "minio client created"
                }
            }
        except Exception as e:
            return {
                "result": {
                    "status_code": 500,
                    "message": traceback.format_exc()
                }
            }

    def create_object_list(self, days: int = 7) -> list:

        print("\n" + "-" * 50)
        query= self.__read_yaml_query__()
        pprint(f"QUERY: {query}", depth=1, compact=True, width=100)

        print("-" * 50 + "\n")

        bucket_name = query["bucket_name"].lower()
        product = query["product"].lower()
        subject = query["subject"].lower()
        source = query["source"].lower()
        start_date = pd.to_datetime(query["start_date"])
        end_date = pd.to_datetime(query["end_date"])

        if (start_date is None) | (end_date is None):
            start_date = dt.datetime.now() - dt.timedelta(days=days)
            end_date = dt.datetime.now()

        if self.__minio_client.bucket_exists(bucket_name):
            print(f'{bcolors.OKGREEN}Bucket [ {bucket_name.upper()} ] Exists!{bcolors.ENDC}\n')
        else:
            print(f'{bcolors.WARNING}Bucket [ {bucket_name.upper()} ] Does Not Exist!{bcolors.ENDC}\n')

        # Initialize an empty list
        date_list = []

        if end_date < start_date:
            print(f'{bcolors.FAIL}[start_date] date must be newer than the [end_date]!{bcolors.ENDC}')
            print(f'{bcolors.WARNING}[SWAPPING DATES]{bcolors.ENDC}')
            start_date, end_date = end_date, start_date

        # Loop through the range of dates and append to the list
        while start_date <= end_date:
            date_list.append({
                "year": start_date.strftime('%Y'),
                "month": start_date.strftime('%m'),
                "day": start_date.strftime('%d')
            })
            start_date += dt.timedelta(days=1)

        # List objects information recursively whose names starts with
        # "my/prefix/".

        objects_list = []

        for date in date_list:

            prefix = f'{product}/{subject}/{source}/{date["year"]}/{date["month"]}/{date["day"]}/'

            objects = self.__minio_client.list_objects(
                bucket_name=bucket_name,
                prefix=prefix,
                recursive=True
            )
            for obj in objects:
                objects_list.append({
                    "bucket_name": bucket_name,
                    "year": date["year"],
                    "month": date["month"],
                    "day": date["day"],
                    "prefix": prefix,
                    "filename": re.sub(prefix, "", obj.object_name),
                    "object_name": obj.object_name
                })

        return objects_list

    def download_objects(self, objects_list: list, export_path: str, max_results: int = 1) -> None:
        # print(objects_list)
        i = 1
        print("-" * 50)
        print(f'Attempting File DOWNLOAD: \n')
        for obj in objects_list:
            print(f'{i:03d}: {obj["object_name"]}')
            response = None
            try:
                response = self.__minio_client.get_object(
                    bucket_name=obj["bucket_name"],
                    object_name=obj["object_name"]
                )
                # Read data from response.
                with open(f"{export_path}/{obj['filename']}", "wb") as f:
                    f.write(response.data)
                
                if i == max_results:
                    break
            finally:
                if response:
                    response.close()
                    response.release_conn()
                i = i + 1
        print("-" * 50 + "\n")

# %%
object_download = ParquetFileObjectsDownload(clear_cache=True)
# Out:
# --------------------------------------------------
# Clearing cache: d:/cache/
# Removed d:/cache//api_2024_01_05_054913_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_05_055125_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_010520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_011829_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_013327_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_013426_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_031826_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_204440_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_205052_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_212206_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_213852_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_215158_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_222200_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_232314_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_233627_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_234140_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_10_234941_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_001936_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_005348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_012342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_015346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_022347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_025342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_032342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_035342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_042342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_045342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_052342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_055342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_062342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_065344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_072342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_075350_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_082352_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_085342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_092342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_095349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_102342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_105349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_112344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_115344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_122345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_125349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_132343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_135342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_142353_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_145350_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_152342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_155343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_162349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_165344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_172342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_175342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_182342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_185342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_192353_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_195351_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_202347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_205342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_212342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_215351_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_222342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_225347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_232356_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_11_235342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_002347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_005343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_012345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_015342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_022344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_025343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_032348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_035342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_042346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_045346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_052342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_055342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_065351_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_072342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_075342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_082342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_085348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_092348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_095342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_102341_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_105348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_112347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_115346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_122342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_125346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_132346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_135342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_142342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_145350_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_152345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_155346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_162347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_165356_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_172345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_175342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_182342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_185342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_192342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_195342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_202349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_205342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_212342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_215342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_222341_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_225353_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_232342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_12_235348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_002344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_005349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_012344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_015342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_022342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_025345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_032352_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_035342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_042349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_045342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_052346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_055342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_062342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_065342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_072345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_075342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_082341_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_085347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_092342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_095350_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_102342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_105345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_112342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_115342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_122347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_125345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_132342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_135342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_142356_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_145343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_152351_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_155343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_162342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_165354_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_172346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_175342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_182342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_185342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_192342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_195344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_202345_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_205349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_212343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_215348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_222342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_225349_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_232350_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_13_235347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_002342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_005353_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_012346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_015342_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_022343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_025348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_032351_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_035353_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_042348_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_045346_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_052341_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_055344_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_062343_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14_065347_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_01_14
datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_03_232516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_03_235530_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_002520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_005521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_012522_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_015520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_022521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_025515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_032521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_035524_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_042517_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_045546_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_052524_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_055523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_062527_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_065525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_072520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_075517_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_082522_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_085515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_092515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_095520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_102518_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_105523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_112525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_115523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_122518_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_125521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_132523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_135523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_142520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_145519_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_152529_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_155515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_162519_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_165534_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_172515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_175525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_182519_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_185515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_192526_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_195516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_202521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_205520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_212516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_215520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_222515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_225515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_232516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_04_235530_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_002521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_005522_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_012516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_015525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_022515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_025533_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_032515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_035527_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_042520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_045538_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_052516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_055521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_062521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_065515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_072515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_075521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_082530_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_085524_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_092515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_095516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_102515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_105518_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_112515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_115520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_122523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_125523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_132521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_135520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_142515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_145515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_152515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_155522_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_162524_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_165547_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_172515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_175538_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_182525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_185534_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_192515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_195515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_202521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_205526_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_212527_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_215515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_222518_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_225523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_232521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_05_235515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_002526_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_005524_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_012523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_015521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_022525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_025525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_032518_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_035521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_042516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_045543_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_052526_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_055529_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_062522_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_065515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_072525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_075515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_082521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_085515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_092519_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_095529_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_102516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_105516_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_112524_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_115531_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_122515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_125530_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_132526_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_135531_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_142530_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_145521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_152515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_155521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_162523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_165547_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_172530_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_175523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_182521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_185522_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_192525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_195542_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_202525_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_205523_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_212528_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_215515_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_222520_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_225528_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_232521_datto_rmm_devices.parquet
# Removed d:/cache//api_2024_02_06_235515_datto_rmm_devices.parquet
# --------------------------------------------------
#
# client is authenticated: <bound method Client.is_authenticated of <hvac.v1.Client object at 0x0000018C7777B890>>
#
# --------------------------------------------------
# ("QUERY: {'bucket_name': 'products', 'product': 'datto_rmm', 'subject': 'devices', 'source': "
#  "'api', 'start_date': '2024/01/01', 'end_date': '2024/02/06'}")
# --------------------------------------------------
#
# Bucket [ PRODUCTS ] Exists!
# --------------------------------------------------
# Attempting File DOWNLOAD:
#
# 001: datto_rmm/devices/api/2024/01/05/api_2024_01_05_054913_datto_rmm_devices.parquet
# --------------------------------------------------

# %%
object_download

# %%
parquet_files = []

for root, dirs, files in os.walk("d:/cache"):
    for file in files:
        parquet_files.append(f'{root}/{file}')

# %%
# TODO: Find best way to create a large dictionary array that can be updated.  Is this using sqlite3 or mongo?  I want something disposable per query.  Is this similar to Athena flat database for query results?

# %%
from cachetools import cached, TTLCache

cache = TTLCache(maxsize=100, ttl=86400)


@cached(cache)
def extract_article_content(url):
    response = requests.get(url)
    content = response.content
    return content

# %%
dataframes = []

for file in parquet_files:
    df = pd.read_parquet(file, dtype_backend="pyarrow")
    dataframes.append(df)

# %%
df_concat = pd.concat(dataframes)

# %%
query = object_download.__read_yaml_query__()

# %%
query

# %%
df_concat.to_csv(
    f'd:/exports/{dt.datetime.utcnow().strftime("%Y_%m_%d_%H%M%S")}_{query["product"]}_{query["subject"]}_{query["source"]}.csv',
    index=False)

# %%
df_tnconnect = df_concat[df_concat["siteName"].str.contains("tnConnect")]

# %%
df_tnconnect[df_tnconnect["lastSeen"] < df_tnconnect["lastAuditDate"]]
